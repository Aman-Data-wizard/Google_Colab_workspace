# %%
import pandas as pd
import numpy as np

# %%
pd.isnull(np.nan)
# Out:
# True

# %%
pd.isna(None)
# Out:
# True

# %%
pd.notnull(3)
# Out:
# True

# %%
pd.notnull(np.nan)
# Out:
# False

# %%
#these functions also work entirely with Pandas Series and Dataframes
pd.isnull(pd.Series([1, np.nan, 7]))
# Out:
# 0    False
# 1     True
# 2    False
# dtype: bool

# %%
pd.notnull(pd.Series([1, np.nan, 7]))
# Out:
# 0     True
# 1    False
# 2     True
# dtype: bool

# %%
pd.isnull(pd.DataFrame ({
    'Column A': [1, np.nan, 7],
    'Column B': [np.nan, 2, 3],
    'Column C': [np.nan, 2, np.nan],
}) )
# Out:
#    Column A  Column B  Column C
# 0     False      True      True
# 1      True     False     False
# 2     False     False      True

# %%
df = pd.DataFrame ({
    'Column A': [1, np.nan, 7],
    'Column B': [np.nan, 2, 3],
    'Column C': [np.nan, 2, np.nan],
    'Column D': [12, 34, 56],
})

# %%
df
# Out:
#    Column A  Column B  Column C  Column D
# 0       1.0       NaN       NaN        12
# 1       NaN       2.0       2.0        34
# 2       7.0       3.0       NaN        56

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Column A  2 non-null      float64
#  1   Column B  2 non-null      float64
#  2   Column C  1 non-null      float64
#  3   Column D  3 non-null      int64
# dtypes: float64(3), int64(1)
# memory usage: 228.0 bytes

# %%
df.shape
# Out:
# (3, 4)

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of    Column A  Column B  Column C  Column D
# 0       1.0       NaN       NaN        12
# 1       NaN       2.0       2.0        34
# 2       7.0       3.0       NaN        56>

# %%
df.isnull().sum()
# Out:
# Column A    1
# Column B    1
# Column C    2
# Column D    0
# dtype: int64

# %%
df.fillna(0)
# Out:
#    Column A  Column B  Column C  Column D
# 0       1.0       0.0       0.0        12
# 1       0.0       2.0       2.0        34
# 2       7.0       3.0       0.0        56

# %%
#All these methods are immutable, we are creating a new series
df.fillna(df.mean())
# Out:
#    Column A  Column B  Column C  Column D
# 0       1.0       2.5       2.0        12
# 1       4.0       2.0       2.0        34
# 2       7.0       3.0       2.0        56

# %%
#original Dataframe is same
df
# Out:
#    Column A  Column B  Column C  Column D
# 0       1.0       NaN       NaN        12
# 1       NaN       2.0       2.0        34
# 2       7.0       3.0       NaN        56

# %% [markdown]
# df.dropna()

# %%
df.dropna(how='all')
# Out:
#    Column A  Column B  Column C  Column D
# 0       1.0       NaN       NaN        12
# 1       NaN       2.0       2.0        34
# 2       7.0       3.0       NaN        56

# %%
df.dropna(thresh=3)
# Out:
#    Column A  Column B  Column C  Column D
# 1       NaN       2.0       2.0        34
# 2       7.0       3.0       NaN        56

# %%
pd.Series([np.nan, 3, np.nan, 9]).fillna(method='ffill')
# Out:
# <ipython-input-31-80c03cda8078>:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   pd.Series([np.nan, 3, np.nan, 9]).fillna(method='ffill')
# 0    NaN
# 1    3.0
# 2    3.0
# 3    9.0
# dtype: float64

# %%
pd.Series([np.nan, 3, np.nan, 9])
# Out:
# 0    NaN
# 1    3.0
# 2    NaN
# 3    9.0
# dtype: float64

# %%
pd.Series([np.nan, 3, np.nan, 9]).fillna(method='bfill')
# Out:
# <ipython-input-36-7abe95401389>:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   pd.Series([np.nan, 3, np.nan, 9]).fillna(method='bfill')
# 0    3.0
# 1    3.0
# 2    9.0
# 3    9.0
# dtype: float64

# %%
df_2 = pd.DataFrame({
    'Sex': ['M', 'F', 'F', 'D', '?'],
    'Age': [29, 30, 24, 290, 25],
})
df_2
# Out:
#   Sex  Age
# 0   M   29
# 1   F   30
# 2   F   24
# 3   D  290
# 4   ?   25

# %%
df_2['Sex'].unique()
# Out:
# array(['M', 'F', 'D', '?'], dtype=object)

# %%
df_2['Sex'].value_counts()
# Out:
# Sex
# F    2
# M    1
# D    1
# ?    1
# Name: count, dtype: int64

# %%
df_2[df_2['Age'] > 100]
# Out:
#   Sex  Age
# 3   D  290

# %%
df_2.loc[df_2['Age'] > 100, 'Age'] = df_2.loc[df_2['Age'] > 100, 'Age'] / 10
df_2
# Out:
#   Sex  Age
# 0   M   29
# 1   F   30
# 2   F   24
# 3   D   29
# 4   ?   25
