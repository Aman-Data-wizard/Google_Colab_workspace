# %%
import pandas as pd
import numpy as np

# %%
#dataframe
df=pd.DataFrame({
    'population': [35.461, 63.951, 80.94, 60.665, 127.061, 64.511, 83.544],
    'GDP': [
        1785387,
        2833687,
        3874437,
        2167744,
        4602367,
        2953422,
        2345445
    ],
    'Surface Area': [
        9984670,
        640679,
        357114,
        301336,
        377930,
        242495,
        152911
    ],
    'HDI' : [
        0.913,
        0.888,
        0.916,
        0.873,
        0.891,
        0.907,
        0.915
    ],
    'Continent': [
        'America',
        'Europe',
        'Europe',
        'Europe',
        'Asia',
        'Europe',
        'America'
        ]
   }, columns=['Population', 'GDP', 'Surface Area', 'HDI', 'Continent']
  )

# %%
print(df)
# Out:
#   Population      GDP  Surface Area    HDI Continent
# 0        NaN  1785387       9984670  0.913   America
# 1        NaN  2833687        640679  0.888    Europe
# 2        NaN  3874437        357114  0.916    Europe
# 3        NaN  2167744        301336  0.873    Europe
# 4        NaN  4602367        377930  0.891      Asia
# 5        NaN  2953422        242495  0.907    Europe
# 6        NaN  2345445        152911  0.915   America

# %%
df.index = [
    'Canada',
    'France',
    'Germany',
    'Italy',
    'Japan',
    'United Kingdom',
    'United States'
]

# %%
print(df)
# Out:
#                Population      GDP  Surface Area    HDI Continent
# Canada                NaN  1785387       9984670  0.913   America
# France                NaN  2833687        640679  0.888    Europe
# Germany               NaN  3874437        357114  0.916    Europe
# Italy                 NaN  2167744        301336  0.873    Europe
# Japan                 NaN  4602367        377930  0.891      Asia
# United Kingdom        NaN  2953422        242495  0.907    Europe
# United States         NaN  2345445        152911  0.915   America

# %%
df.columns
# Out:
# Index(['Population', 'GDP', 'Surface Area', 'HDI', 'Continent'], dtype='object')

# %% [markdown]
# df.index

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, Canada to United States
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Population    0 non-null      object
#  1   GDP           7 non-null      int64
#  2   Surface Area  7 non-null      int64
#  3   HDI           7 non-null      float64
#  4   Continent     7 non-null      object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 636.0+ bytes

# %%
df.size
# Out:
# 35

# %%
df.shape
# Out:
# (7, 5)

# %% [markdown]
# df.dtypes

# %%
df.describe()
# Out:
#                 GDP  Surface Area       HDI
# count  7.000000e+00  7.000000e+00  7.000000
# mean   2.937498e+06  1.722448e+06  0.900429
# std    9.942402e+05  3.646452e+06  0.016592
# min    1.785387e+06  1.529110e+05  0.873000
# 25%    2.256594e+06  2.719155e+05  0.889500
# 50%    2.833687e+06  3.571140e+05  0.907000
# 75%    3.413930e+06  5.093045e+05  0.914000
# max    4.602367e+06  9.984670e+06  0.916000

# %%
df.dtypes.value_counts()
# Out:
# object     2
# int64      2
# float64    1
# Name: count, dtype: int64

# %%
df.loc['Canada']
df
# Out:
#                Population      GDP  Surface Area    HDI Continent
# Canada                NaN  1785387       9984670  0.913   America
# France                NaN  2833687        640679  0.888    Europe
# Germany               NaN  3874437        357114  0.916    Europe
# Italy                 NaN  2167744        301336  0.873    Europe
# Japan                 NaN  4602367        377930  0.891      Asia
# United Kingdom        NaN  2953422        242495  0.907    Europe
# United States         NaN  2345445        152911  0.915   America
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['GDP'].plot(kind='hist', bins=20, title='GDP')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df['Surface Area'].plot(kind='hist', bins=20, title='Surface Area')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df['HDI'].plot(kind='hist', bins=20, title='HDI')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# df.groupby('Continent').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df.plot(kind='scatter', x='GDP', y='Surface Area', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df.plot(kind='scatter', x='Surface Area', y='HDI', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df['GDP'].plot(kind='line', figsize=(8, 4), title='GDP')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# df['Surface Area'].plot(kind='line', figsize=(8, 4), title='Surface Area')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# df['HDI'].plot(kind='line', figsize=(8, 4), title='HDI')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(df['Continent'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(df, x='GDP', y='Continent', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(df['Continent'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(df, x='Surface Area', y='Continent', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(df['Continent'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(df, x='HDI', y='Continent', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
df.iloc[-1]
df
# Out:
#                Population      GDP  Surface Area    HDI Continent
# Canada                NaN  1785387       9984670  0.913   America
# France                NaN  2833687        640679  0.888    Europe
# Germany               NaN  3874437        357114  0.916    Europe
# Italy                 NaN  2167744        301336  0.873    Europe
# Japan                 NaN  4602367        377930  0.891      Asia
# United Kingdom        NaN  2953422        242495  0.907    Europe
# United States         NaN  2345445        152911  0.915   America

# %%
df.loc['France': 'Italy']
# Out:
#         Population      GDP  Surface Area    HDI Continent
# France         NaN  2833687        640679  0.888    Europe
# Germany        NaN  3874437        357114  0.916    Europe
# Italy          NaN  2167744        301336  0.873    Europe

# %% [markdown]
# df.iloc[-1]
# df

# %%
df['Population']
# Out:
# Canada            NaN
# France            NaN
# Germany           NaN
# Italy             NaN
# Japan             NaN
# United Kingdom    NaN
# United States     NaN
# Name: Population, dtype: object

# %%
df['Population'].to_frame()
# Out:
#                Population
# Canada                NaN
# France                NaN
# Germany               NaN
# Italy                 NaN
# Japan                 NaN
# United Kingdom        NaN
# United States         NaN
