# %%
import numpy as np

# %%
n = 3

# %%
2 ** 3
# Out:
# 8

# %%
120
# Out:
# 120

# %%
x = 5

# %%
np.int8
# Out:
# numpy.int8

# %%
np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
a = np.array([1,2,3,4])
b = np.array([0, 1.5, 1, 2.5])

# %%
a[0], a[1]
# Out:
# (np.int64(1), np.int64(2))

# %%
a[0:]
# Out:
# array([1, 2, 3, 4])

# %% [markdown]
# b[0], b[3]

# %%
a[::3]
# Out:
# array([1, 4])

# %%
A = np.array([
    ['a', 'b', 'c'],
    ['d', 'e', 'f'],
    ['g', 'h', 'i']
])

print(A[:, :2])
# Out:
# [['a' 'b']
#  ['d' 'e']
#  ['g' 'h']]

# %%
a = np.arange(5)
a + 20
# Out:
# array([20, 21, 22, 23, 24])

# %%
a = np.arange(5)
print(a<=3)
# Out:
# [ True  True  True  True False]
