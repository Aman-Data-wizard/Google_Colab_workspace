# %%
import pandas as pd
import numpy as np

# %%
certificates_earned = pd.Series(
    [8, 2, 5, 6],
    index=['Tom', 'Kris', 'Ahmad', 'Buzz']
)
print(certificates_earned)
# Out:
# Tom      8
# Kris     2
# Ahmad    5
# Buzz     6
# dtype: int64

# %%
g7_pop = pd.Series([37.467, 63.951, 80.940, 34.43, 89.789, 90.788])
g7_pop
# Out:
# 0    37.467
# 1    63.951
# 2    80.940
# 3    34.430
# 4    89.789
# 5    90.788
# dtype: float64

# %%
g7_pop.dtype
# Out:
# dtype('float64')

# %%
g7_pop.name = 'G7 population in millions'
g7_pop
# Out:
# 0    37.467
# 1    63.951
# 2    80.940
# 3    34.430
# 4    89.789
# 5    90.788
# Name: G7 population in millions, dtype: float64

# %%
g7_pop.dtype
# Out:
# dtype('float64')

# %%
g7_pop.values
# Out:
# array([37.467, 63.951, 80.94 , 34.43 , 89.789, 90.788])

# %%
type(g7_pop.values)
# Out:
# numpy.ndarray

# %%
g7_pop
# Out:
# 0    37.467
# 1    63.951
# 2    80.940
# 3    34.430
# 4    89.789
# 5    90.788
# Name: G7 population in millions, dtype: float64

# %%
g7_pop[0]
# Out:
# np.float64(37.467)

# %%
g7_pop[1]
# Out:
# np.float64(63.951)

# %%
g7_pop.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
g7_pop.index = [
    'Canada',
    'France',
    'Germany',
    'Japan',
    'United kingdom',
    'United states',
]
g7_pop
# Out:
# Canada            37.467
# France            63.951
# Germany           80.940
# Japan             34.430
# United kingdom    89.789
# United states     90.788
# Name: G7 population in millions, dtype: float64

# %%
g7_pop.iloc[0]
# Out:
# np.float64(37.467)

# %%
g7_pop.iloc[-1]
# Out:
# np.float64(90.788)

# %%
certificates_earned = pd.Series(
    [8,2,5,6],
    index = ['Tom', 'Kris', 'Ahmad', 'Beau']
)
print(certificates_earned [certificates_earned > 5])
# Out:
# Tom     8
# Beau    6
# dtype: int64
