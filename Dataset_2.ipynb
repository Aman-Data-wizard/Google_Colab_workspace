# %%
import pandas as pd
import numpy as np

# %%
#dataframe
df=pd.DataFrame({
    'population': [35.461, 63.951, 80.94, 60.665, 127.061, 64.511, 83.544],
    'GDP': [
        1785387,
        2833687,
        3874437,
        2167744,
        4602367,
        2953422,
        2345445
    ],
    'Surface Area': [
        9984670,
        640679,
        357114,
        301336,
        377930,
        242495,
        152911
    ],
    'HDI' : [
        0.913,
        0.888,
        0.916,
        0.873,
        0.891,
        0.907,
        0.915
    ],
    'Continent': [
        'America',
        'Europe',
        'Europe',
        'Europe',
        'Asia',
        'Europe',
        'America'
        ]
   }, columns=['Population', 'GDP', 'Surface Area', 'HDI', 'Continent']
  )

# %%
print(df)
# Out:
#   Population      GDP  Surface Area    HDI Continent
# 0        NaN  1785387       9984670  0.913   America
# 1        NaN  2833687        640679  0.888    Europe
# 2        NaN  3874437        357114  0.916    Europe
# 3        NaN  2167744        301336  0.873    Europe
# 4        NaN  4602367        377930  0.891      Asia
# 5        NaN  2953422        242495  0.907    Europe
# 6        NaN  2345445        152911  0.915   America

# %%
df.index = [
    'Canada',
    'France',
    'Germany',
    'Italy',
    'Japan',
    'United Kingdom',
    'United States'
]

# %%
print(df)
# Out:
#                Population      GDP  Surface Area    HDI Continent
# Canada                NaN  1785387       9984670  0.913   America
# France                NaN  2833687        640679  0.888    Europe
# Germany               NaN  3874437        357114  0.916    Europe
# Italy                 NaN  2167744        301336  0.873    Europe
# Japan                 NaN  4602367        377930  0.891      Asia
# United Kingdom        NaN  2953422        242495  0.907    Europe
# United States         NaN  2345445        152911  0.915   America

# %%
df.columns
# Out:
# Index(['Population', 'GDP', 'Surface Area', 'HDI', 'Continent'], dtype='object')

# %% [markdown]
# df.index

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, Canada to United States
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Population    0 non-null      object
#  1   GDP           7 non-null      int64
#  2   Surface Area  7 non-null      int64
#  3   HDI           7 non-null      float64
#  4   Continent     7 non-null      object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 636.0+ bytes

# %%
df.size
# Out:
# 35

# %%
df.shape
# Out:
# (7, 5)

# %% [markdown]
# df.dtypes

# %%
df.describe()
# Out:
#                 GDP  Surface Area       HDI
# count  7.000000e+00  7.000000e+00  7.000000
# mean   2.937498e+06  1.722448e+06  0.900429
# std    9.942402e+05  3.646452e+06  0.016592
# min    1.785387e+06  1.529110e+05  0.873000
# 25%    2.256594e+06  2.719155e+05  0.889500
# 50%    2.833687e+06  3.571140e+05  0.907000
# 75%    3.413930e+06  5.093045e+05  0.914000
# max    4.602367e+06  9.984670e+06  0.916000

# %%
df.dtypes.value_counts()
# Out:
# object     2
# int64      2
# float64    1
# Name: count, dtype: int64

# %%
df.loc['Canada']
df
# Out:
#                Population      GDP  Surface Area    HDI Continent
# Canada                NaN  1785387       9984670  0.913   America
# France                NaN  2833687        640679  0.888    Europe
# Germany               NaN  3874437        357114  0.916    Europe
# Italy                 NaN  2167744        301336  0.873    Europe
# Japan                 NaN  4602367        377930  0.891      Asia
# United Kingdom        NaN  2953422        242495  0.907    Europe
# United States         NaN  2345445        152911  0.915   America

# %%
df.iloc[-1]
df
# Out:
#                Population      GDP  Surface Area    HDI Continent
# Canada                NaN  1785387       9984670  0.913   America
# France                NaN  2833687        640679  0.888    Europe
# Germany               NaN  3874437        357114  0.916    Europe
# Italy                 NaN  2167744        301336  0.873    Europe
# Japan                 NaN  4602367        377930  0.891      Asia
# United Kingdom        NaN  2953422        242495  0.907    Europe
# United States         NaN  2345445        152911  0.915   America

# %%
df.loc['France': 'Italy']
# Out:
#         Population      GDP  Surface Area    HDI Continent
# France         NaN  2833687        640679  0.888    Europe
# Germany        NaN  3874437        357114  0.916    Europe
# Italy          NaN  2167744        301336  0.873    Europe

# %% [markdown]
# df.iloc[-1]
# df

# %%
df['Population']
# Out:
# Canada            NaN
# France            NaN
# Germany           NaN
# Italy             NaN
# Japan             NaN
# United Kingdom    NaN
# United States     NaN
# Name: Population, dtype: object

# %%
df['Population'].to_frame()
# Out:
#                Population
# Canada                NaN
# France                NaN
# Germany               NaN
# Italy                 NaN
# Japan                 NaN
# United Kingdom        NaN
# United States         NaN

# %%
#pandas conditional selection and modifying Dataframes.

df['Population'] > 70
# Out:
# Canada            False
# France            False
# Germany           False
# Italy             False
# Japan             False
# United Kingdom    False
# United States     False
# Name: Population, dtype: bool

# %%
df.loc[df['Population'] > 70, 'Population']
# Out:
# Series([], Name: Population, dtype: object)

# %%
df.drop('Canada')
# Out:
#                Population      GDP  Surface Area    HDI Continent
# France                NaN  2833687        640679  0.888    Europe
# Germany               NaN  3874437        357114  0.916    Europe
# Italy                 NaN  2167744        301336  0.873    Europe
# Japan                 NaN  4602367        377930  0.891      Asia
# United Kingdom        NaN  2953422        242495  0.907    Europe
# United States         NaN  2345445        152911  0.915   America

# %%
df.drop(columns=['Population', 'HDI'])
# Out:
#                     GDP  Surface Area Continent
# Canada          1785387       9984670   America
# France          2833687        640679    Europe
# Germany         3874437        357114    Europe
# Italy           2167744        301336    Europe
# Japan           4602367        377930      Asia
# United Kingdom  2953422        242495    Europe
# United States   2345445        152911   America

# %%
crisis = pd.Series([-1_000_000, -0.3], index=['GDP', 'HDI'])
crisis
# Out:
# GDP   -1000000.0
# HDI         -0.3
# dtype: float64

# %%
df[['GDP', 'HDI']]
# Out:
#                     GDP    HDI
# Canada          1785387  0.913
# France          2833687  0.888
# Germany         3874437  0.916
# Italy           2167744  0.873
# Japan           4602367  0.891
# United Kingdom  2953422  0.907
# United States   2345445  0.915

# %%
df[['GDP', 'HDI']] + crisis
# Out:
#                       GDP    HDI
# Canada           785387.0  0.613
# France          1833687.0  0.588
# Germany         2874437.0  0.616
# Italy           1167744.0  0.573
# Japan           3602367.0  0.591
# United Kingdom  1953422.0  0.607
# United States   1345445.0  0.615

# %%
lang = pd.Series(
    ['French', 'German', 'Italian'],
    index = ['France', 'Germany', 'Italy'],
    name = 'language'
)

# %%
lang
# Out:
# France      French
# Germany     German
# Italy      Italian
# Name: language, dtype: object

# %%
df['language'] = lang
df
# Out:
#                Population      GDP  Surface Area    HDI Continent language
# Canada                NaN  1785387       9984670  0.913   America      NaN
# France                NaN  2833687        640679  0.888    Europe   French
# Germany               NaN  3874437        357114  0.916    Europe   German
# Italy                 NaN  2167744        301336  0.873    Europe  Italian
# Japan                 NaN  4602367        377930  0.891      Asia      NaN
# United Kingdom        NaN  2953422        242495  0.907    Europe      NaN
# United States         NaN  2345445        152911  0.915   America      NaN

# %%
df['language'] = 'English'
df
# Out:
#                Population      GDP  Surface Area    HDI Continent language
# Canada                NaN  1785387       9984670  0.913   America  English
# France                NaN  2833687        640679  0.888    Europe  English
# Germany               NaN  3874437        357114  0.916    Europe  English
# Italy                 NaN  2167744        301336  0.873    Europe  English
# Japan                 NaN  4602367        377930  0.891      Asia  English
# United Kingdom        NaN  2953422        242495  0.907    Europe  English
# United States         NaN  2345445        152911  0.915   America  English

# %%
df.rename(
    columns={
        'HDI': 'Human Development Index',
        'Annual Population': 'Population'
    }, index={
        'United States': 'USA',
        'United Kingdom': 'UK',
        'Argentina': 'AR'
    }

    )
# Out:
#         Population      GDP  Surface Area  Human Development Index Continent  \
# Canada         NaN  1785387       9984670                    0.913   America
# France         NaN  2833687        640679                    0.888    Europe
# Germany        NaN  3874437        357114                    0.916    Europe
# Italy          NaN  2167744        301336                    0.873    Europe
# Japan          NaN  4602367        377930                    0.891      Asia
# UK             NaN  2953422        242495                    0.907    Europe
# USA            NaN  2345445        152911                    0.915   America
#
#         language
# Canada   English
# France   English
# Germany  English
# Italy    English
# Japan    English
# UK       English
# USA      English

# %%
df.rename(index = str.upper)
# Out:
#                Population      GDP  Surface Area    HDI Continent language
# CANADA                NaN  1785387       9984670  0.913   America  English
# FRANCE                NaN  2833687        640679  0.888    Europe  English
# GERMANY               NaN  3874437        357114  0.916    Europe  English
# ITALY                 NaN  2167744        301336  0.873    Europe  English
# JAPAN                 NaN  4602367        377930  0.891      Asia  English
# UNITED KINGDOM        NaN  2953422        242495  0.907    Europe  English
# UNITED STATES         NaN  2345445        152911  0.915   America  English

# %%
df.rename(index = lambda x: x.lower())
# Out:
#                Population      GDP  Surface Area    HDI Continent language
# canada                NaN  1785387       9984670  0.913   America  English
# france                NaN  2833687        640679  0.888    Europe  English
# germany               NaN  3874437        357114  0.916    Europe  English
# italy                 NaN  2167744        301336  0.873    Europe  English
# japan                 NaN  4602367        377930  0.891      Asia  English
# united kingdom        NaN  2953422        242495  0.907    Europe  English
# united states         NaN  2345445        152911  0.915   America  English
